# %%
import pyodbc
import pandas as pd
import numpy as np

# %%
import statistics
import scipy.stats as stat
import scipy as sp

# %%
server = 'sql-mcibusxrm-dev.database.windows.net'
database = 'sqldb-mcibusprestock-dev'
username = 'sql-mcibusxrm-dev'
password = '{pzR28UcutX26GdAJLWm9SXw}'
driver= '{ODBC Driver 17 for SQL Server}'

conn = pyodbc.connect('DRIVER='+driver+';SERVER=tcp:'+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = conn.cursor()

# %%
df_BPM = pd.read_sql("SELECT top 1000 BienPrestockMandatId, Origine_UrlOrigineAnnonce, Origine_DateCollecte  FROM dbo.BienPrestockMandat", conn)

# %%
df_BPM.head()
# Out:
#    BienPrestockMandatId                          Origine_UrlOrigineAnnonce  \
# 0                528638  https://www.leboncoin.fr/ventes_immobilieres/6...
# 1                528639  https://www.leboncoin.fr/ventes_immobilieres/6...
# 2                530597  http://www.logic-immo.com/detail-vente-f8e1176...
# 3                531176  https://www.leboncoin.fr/ventes_immobilieres/6...
# 4                531177  https://www.leboncoin.fr/ventes_immobilieres/6...
#
#   Origine_DateCollecte
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None

# %%
df = pd.read_csv("dbo.BienPrestockMandat.csv")
# Out:
# C:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (39,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.set_option('display.max_columns', None)

df.head()
# Out:
#    BienPreStockMandatId                          Origine_UrlOrigineAnnonce  \
# 0                528638  https://www.leboncoin.fr/ventes_immobilieres/6...
# 1                528639  https://www.leboncoin.fr/ventes_immobilieres/6...
# 2                530597  http://www.logic-immo.com/detail-vente-f8e1176...
# 3                531176  https://www.leboncoin.fr/ventes_immobilieres/6...
# 4                531177  https://www.leboncoin.fr/ventes_immobilieres/6...
#
#   Origine_DateCollecte  Origine_OrigineCreationAnnonce Origine_Commentaire  \
# 0                  NaN                               1                 NaN
# 1                  NaN                               1                 NaN
# 2                  NaN                               1                 NaN
# 3                  NaN                               1                 NaN
# 4                  NaN                               1                 NaN
#
#             DescriptionBien_Titre  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30436 entries, 0 to 30435
# Data columns (total 45 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   BienPreStockMandatId                      30436 non-null  int64
#  1   Origine_UrlOrigineAnnonce                 30436 non-null  object
#  2   Origine_DateCollecte                      30425 non-null  object
#  3   Origine_OrigineCreationAnnonce            30436 non-null  int64
#  4   Origine_Commentaire                       26602 non-null  object
#  5   DescriptionBien_Titre                     30436 non-null  object
#  6   DescriptionBien_Description               30234 non-null  object
#  7   DescriptionBien_Adresse_Numero            0 non-null      float64
#  8   DescriptionBien_Adresse_Rue               0 non-null      float64
#  9   DescriptionBien_Adresse_BoitePostale      0 non-null      float64
# ...

# %%
df["Origine_OrigineCreationAnnonce"].value_counts()
# Out:
# 1    30436
# Name: Origine_OrigineCreationAnnonce, dtype: int64

# %%
df["Origine_DateCollecte"].value_counts()
# Out:
# 2020-07-01 17:23:45.707    112
# 2020-08-31 18:01:53.960    110
# 2020-07-25 19:47:35.453    109
# 2020-07-25 19:47:39.667    108
# 2020-08-31 18:02:30.013    108
#                           ...
# 2021-01-06 21:49:32.027      1
# 2020-06-05 13:03:58.760      1
# 2020-09-09 08:18:26.730      1
# 2020-10-29 07:18:34.793      1
# 2021-01-06 14:49:54.540      1
# Name: Origine_DateCollecte, Length: 14597, dtype: int64

# %%
df["Origine_OrigineCreationAnnonce"].value_counts()
# Out:
# 1    30436
# Name: Origine_OrigineCreationAnnonce, dtype: int64

# %%
df["DescriptionBien_PrixNegocie"].value_counts()
# Out:
# 0    30436
# Name: DescriptionBien_PrixNegocie, dtype: int64

# %% [raw]
# Analyse des données
#
#     *BienPreStockMandatId
# Origine_UrlOrigineAnnonce
# Origine_DateCollecte             == date à laquelle les annonces ont été collecté
# Origine_OrigineCreationAnnonce   == 1 seule valeur == 1 ???
# Origine_Commentaire              == ???
# DescriptionBien_Titre
#     *DescriptionBien_Adresse_Numero == pas de data
#     *DescriptionBien_Adresse_Rue == pas de data
#     *DescriptionBien_Adresse_BoitePostale == pas de data
# DescriptionBien_Adresse_CodePostal
# DescriptionBien_Adresse_Ville
# DescriptionBien_Adresse_Pays
# DescriptionBien_Adresse_Complement
# DescriptionBien_TypeBienEnum
# DescriptionBien_NombrePiecesEnum
# DescriptionBien_NombrePiecesComplement
# DescriptionBien_Localisation
# DescriptionBien_Surface
# DescriptionBien_SurfaceComplement
# DescriptionBien_Prix
# DescriptionBien_AutreCritere1
# DescriptionBien_AutreCritere2
# DescriptionBien_AutreCritere3
# DescriptionBien_AutreCritere4
# DescriptionBien_AutreCritere5
# DescriptionBien_Situation
#  29  DescriptionBien_Style
#  30  Statut
#  31  MandatId
#  32  DescriptionBien_AnneeConstruction
#  33  DescriptionBien_DateLivraison
#  34  DescriptionBien_PrixNegocie
#  35  DescriptionBien_Intermediaire
#  36  Origine_OrigineHostAnnonce
#  37  DescriptionBien_PrixNetVendeurNegocie
#  38  DescriptionBien_DateOffreAcceptee
#  39  Origine_SourceName
#  40  Origine_DatePublication
#  41  Origine_ExternalId
#      42  ContactBien_Nom
#      43  ContactBien_Email
#      44  ContactBien_Telephone

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30436 entries, 0 to 30435
# Data columns (total 45 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   BienPreStockMandatId                      30436 non-null  int64
#  1   Origine_UrlOrigineAnnonce                 30436 non-null  object
#  2   Origine_DateCollecte                      30425 non-null  object
#  3   Origine_OrigineCreationAnnonce            30436 non-null  int64
#  4   Origine_Commentaire                       26602 non-null  object
#  5   DescriptionBien_Titre                     30436 non-null  object
#  6   DescriptionBien_Description               30234 non-null  object
#  7   DescriptionBien_Adresse_Numero            0 non-null      float64
#  8   DescriptionBien_Adresse_Rue               0 non-null      float64
#  9   DescriptionBien_Adresse_BoitePostale      0 non-null      float64
# ...
