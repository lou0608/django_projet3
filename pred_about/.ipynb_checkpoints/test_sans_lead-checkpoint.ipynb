# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import scipy.stats as stat
import scipy as sp
import statistics

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Modèle de ML
from sklearn import linear_model

# data pre-processing
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# Outils score et evaluation de modèle
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import r2_score

# Outils optmisation de modèle
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("dataset_mci_extended.csv", sep = ",")
df.head()
# Out:
#    DateMandatInstant  DateMandatSeason  DateMandatYear  DateMandatMonth  \
# 0                  1                 2               0                4
# 1                  1                 2               0                4
# 2                  1                 2               0                4
# 3                  2                 2               0                4
# 4                  7                 2               0                5
#
#    DateMandatWeek  MandatId  \
# 0              17         2
# 1              17         2
# 2              17         3
# 3              17         5
# 4              18        12
#
#                                            UrlMandat  DateMandat  \
# 0  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-26
# 1  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-26
# 2  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-26
# 3  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-27
# 4  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-05-02
#
#    StatutMandat DateCompromis  BudgetMaxEuro     TypeBien  \
# 0  Mandat perdu           NaN         280000       Maison
# 1  Mandat perdu           NaN         280000       Maison
# 2    Lead perdu           NaN         300000  Appartement
# 3  Mandat perdu           NaN         250000  Appartement
# 4    Lead perdu           NaN         250000       Maison
#
#              TypeProjet  SurfaceMin NombrePieces NombreChambres        Ville  \
# 0  Résidence principale           0            5              2        Nimes
# 1  Résidence principale           0            5              2  Montpellier
# 2  Résidence principale          70            3              2  Montpellier
# 3        Investissement          60            3              2  Montpellier
# 4  Résidence principale          80            4              3   Frontignan
#
#    CodePostal Departement                Region  NombreDeBiensTrouves  \
# 0       30000        Gard  Languedoc-Roussillon                    39
# 1       34000     Hérault  Languedoc-Roussillon                    39
# 2       34000     Hérault  Languedoc-Roussillon                     2
# 3       34000     Hérault  Languedoc-Roussillon                    18
# 4       34110     Hérault  Languedoc-Roussillon                     0
#
#    NombreDeBiensPublies  NombreDeBiensSelectionnes  NombreDeBiensAVisiter  \
# 0                    32                          5                      4
# 1                    32                          5                      4
# 2                     1                          0                      0
# 3                    17                          2                      0
# 4                     0                          0                      0
#
#    NombreDeBiensVisites  NombreDeBiensRejetes  NombreDeBiensActesOuCompromis  \
# 0                     1                    18                              0
# 1                     1                    18                              0
# 2                     0                     0                              0
# 3                     1                    11                              0
# 4                     0                     0                              0
#
#   DatePremierePublicationDeBien DateDernierePublicationDeBien  \
# 0                    2012-05-21                    2015-10-09
# 1                    2012-05-21                    2015-10-09
# 2                    2013-03-07                    2013-03-07
# 3                    2012-05-03                    2014-11-18
# 4                           NaN                           NaN
#
#    DelaiPremierePublicationDeBien DatePremiereVisite  DelaiPremiereVisite
# 0                            25.0                NaN                  NaN
# 1                            25.0                NaN                  NaN
# 2                           315.0                NaN                  NaN
# 3                             6.0                NaN                  NaN
# 4                             NaN                NaN                  NaN

# %%
indexNames = df[df['StatutMandat'] == 'Lead perdu'].index
df.drop(indexNames, inplace = True)

# %%
plot = df['StatutMandat'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='StatutMandat')

# %%
df['StatutMandat'].replace("Mandat perdu",0 ,inplace=True)
df['StatutMandat'].replace("Entrée dans les lieux",1 ,inplace=True)
df['StatutMandat'].replace("Preparation de l'acte",1 ,inplace=True)

# %%
plot = df['StatutMandat'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='StatutMandat')

# %%
plot = df['TypeBien'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='TypeBien')

# %%
plot = df['TypeBien'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='TypeBien')

# %%
plot = df['TypeProjet'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='TypeProjet')

# %%
plot = df['TypeProjet'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='TypeProjet')

# %%
df['TypeBien'].replace("Appartement",0 ,inplace=True)
df['TypeBien'].replace("Maison",1 ,inplace=True)
df['TypeBien'].replace("Maison ou appartement",2 ,inplace=True)
df['TypeBien'].replace("Immeuble",3 ,inplace=True)
df['TypeBien'].replace("Studio",4 ,inplace=True)
df['TypeBien'].replace("Terrain",5 ,inplace=True)
df['TypeBien'].replace("Local",6 ,inplace=True)
df['TypeBien'].replace("Autre",7 ,inplace=True)

df['TypeProjet'].replace("Résidence principale",0 ,inplace=True)
df['TypeProjet'].replace("Investissement",1 ,inplace=True)
df['TypeProjet'].replace("Résidence secondaire",2 ,inplace=True)

df["NombreChambres"].replace("6+", 6, inplace = True)
df["NombreChambres"] = df["NombreChambres"].astype(int)

df["NombrePieces"].replace("6+", 6, inplace = True)
df["NombrePieces"] = df["NombrePieces"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23055 entries, 0 to 51772
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DateMandatInstant               23055 non-null  int64
#  1   DateMandatSeason                23055 non-null  int64
#  2   DateMandatYear                  23055 non-null  int64
#  3   DateMandatMonth                 23055 non-null  int64
#  4   DateMandatWeek                  23055 non-null  int64
#  5   MandatId                        23055 non-null  int64
#  6   UrlMandat                       23055 non-null  object
#  7   DateMandat                      23055 non-null  object
#  8   StatutMandat                    23055 non-null  int64
#  9   DateCompromis                   6645 non-null   object
#  10  BudgetMaxEuro                   23055 non-null  int64
#  11  TypeBien                        23055 non-null  int64
#  12  TypeProjet                      23055 non-null  int64
#  13  SurfaceMin                      23055 non-null  int64
#  14  NombrePieces                    23055 non-null  int32
#  15  NombreChambres                  23055 non-null  int32
#  16  Ville                           23055 non-null  object
#  17  CodePostal                      23055 non-null  int64
#  18  Departement                     23055 non-null  object
#  19  Region                          23055 non-null  object
#  20  NombreDeBiensTrouves            23055 non-null  int64
#  21  NombreDeBiensPublies            23055 non-null  int64
#  22  NombreDeBiensSelectionnes       23055 non-null  int64
#  23  NombreDeBiensAVisiter           23055 non-null  int64
#  24  NombreDeBiensVisites            23055 non-null  int64
#  25  NombreDeBiensRejetes            23055 non-null  int64
#  26  NombreDeBiensActesOuCompromis   23055 non-null  int64
#  27  DatePremierePublicationDeBien   22161 non-null  object
#  28  DateDernierePublicationDeBien   22161 non-null  object
#  29  DelaiPremierePublicationDeBien  22161 non-null  float64
#  30  DatePremiereVisite              12678 non-null  object
#  31  DelaiPremiereVisite             12678 non-null  float64
# dtypes: float64(2), int32(2), int64(19), object(9)
# memory usage: 6.1+ MB

# %%
df.describe()
# Out:
#        DateMandatInstant  DateMandatSeason  DateMandatYear  DateMandatMonth  \
# count       23055.000000      23055.000000    23055.000000     23055.000000
# mean         2540.263630          2.395836        6.808675         6.065018
# std           675.533319          1.152725        1.886714         3.511680
# min             1.000000          1.000000        0.000000         1.000000
# 25%          2213.000000          1.000000        6.000000         3.000000
# 50%          2726.000000          2.000000        7.000000         6.000000
# 75%          3068.000000          3.000000        8.000000         9.000000
# max          3364.000000          4.000000        9.000000        12.000000
#
#        DateMandatWeek      MandatId  StatutMandat  BudgetMaxEuro  \
# count    23055.000000  23055.000000  23055.000000   2.305500e+04
# mean        24.999176  56693.427196      0.348167   4.196283e+05
# std         15.252937  20628.247148      0.476400   4.262866e+05
# min          1.000000      2.000000      0.000000   1.000000e+03
# 25%         11.000000  43471.000000      0.000000   2.200000e+05
# 50%         24.000000  61153.000000      0.000000   3.100000e+05
# 75%         39.000000  74262.000000      1.000000   5.000000e+05
# max         53.000000  83571.000000      1.000000   1.500000e+07
#
#            TypeBien    TypeProjet     SurfaceMin    CodePostal  \
# count  23055.000000  23055.000000   23055.000000  23055.000000
# mean       0.676252      0.314769      77.190024  59812.631403
# std        0.964215      0.567578     660.916606  25959.430430
# min        0.000000      0.000000       0.000000   1000.000000
# 25%        0.000000      0.000000      40.000000  34730.000000
# 50%        0.000000      0.000000      65.000000  69140.000000
# 75%        1.000000      1.000000      90.000000  75016.000000
# max        7.000000      2.000000  100000.000000  95880.000000
#
#        NombreDeBiensTrouves  NombreDeBiensPublies  NombreDeBiensSelectionnes  \
# count           23055.00000          23055.000000               23055.000000
# mean               61.15129             14.697853                   3.351204
# std                67.87104             15.591047                   4.064113
# min                 0.00000              0.000000                   0.000000
# 25%                21.00000              5.000000                   1.000000
# 50%                42.00000             10.000000                   2.000000
# 75%                78.00000             19.000000                   5.000000
# max              1258.00000            260.000000                  52.000000
#
#        NombreDeBiensAVisiter  NombreDeBiensVisites  NombreDeBiensRejetes  \
# count           23055.000000          23055.000000          23055.000000
# mean                0.745782              1.940794              8.712340
# std                 1.489139              2.828674             11.266899
# min                 0.000000              0.000000              0.000000
# 25%                 0.000000              0.000000              2.000000
# 50%                 0.000000              1.000000              5.000000
# 75%                 1.000000              3.000000             11.000000
# max                25.000000             49.000000            162.000000
#
#        NombreDeBiensActesOuCompromis  DelaiPremierePublicationDeBien  \
# count                   23055.000000                    22161.000000
# mean                        0.365040                       29.679662
# std                         0.482712                       69.781206
# min                         0.000000                       -4.000000
# 25%                         0.000000                        6.000000
# 50%                         0.000000                       12.000000
# 75%                         1.000000                       26.000000
# max                         2.000000                     1833.000000
#
#        DelaiPremiereVisite
# count         12678.000000
# mean             53.983594
# std              82.618403
# min              -4.000000
# 25%              16.000000
# 50%              30.000000
# 75%              61.000000
# max            1851.000000

# %%
plt.figure(figsize = (25,15))
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
df.corr()['StatutMandat']
# Out:
# DateMandatInstant                 0.048622
# DateMandatSeason                 -0.020171
# DateMandatYear                    0.048537
# DateMandatMonth                  -0.004794
# DateMandatWeek                   -0.006085
# MandatId                          0.045193
# StatutMandat                      1.000000
# BudgetMaxEuro                    -0.016609
# TypeBien                         -0.126090
# TypeProjet                       -0.015344
# SurfaceMin                       -0.011848
# CodePostal                        0.071970
# NombreDeBiensTrouves              0.041854
# NombreDeBiensPublies              0.040303
# NombreDeBiensSelectionnes         0.214175
# NombreDeBiensAVisiter             0.049624
# NombreDeBiensVisites              0.264146
# NombreDeBiensRejetes              0.010086
# NombreDeBiensActesOuCompromis     0.851033
# DelaiPremierePublicationDeBien   -0.039266
# DelaiPremiereVisite              -0.073175
# Name: StatutMandat, dtype: float64

# %%
df["NombreDeBiensTrouves"].max()
# Out:
# 1258

# %%
df["NombreDeBiensTrouves"].std()
# Out:
# 67.87103963495038

# %%
df["NombreDeBiensTrouves"].min()
# Out:
# 0

# %%
df.
# Out:
#   File "<ipython-input-23-38e9e33c87a8>", line 1
#     df.
#        ^
# SyntaxError: invalid syntax

# %%
df.loc[df['NombreDeBiensTrouves'] > 100]
# Out:
#        DateMandatInstant  DateMandatSeason  DateMandatYear  DateMandatMonth  \
# 66                   139                 3               0                9
# 189                  293                 1               1                2
# 190                  293                 1               1                2
# 191                  293                 1               1                2
# 253                  326                 1               1                3
# ...                  ...               ...             ...              ...
# 50764               3297                 2               9                5
# 51103               3308                 2               9                5
# 51104               3308                 2               9                5
# 51105               3308                 2               9                5
# 51144               3310                 2               9                5
#
#        DateMandatWeek  MandatId  \
# 66                 37       687
# 189                 7      1732
# 190                 7      1732
# 191                 7      1732
# 253                12      1964
# ...               ...       ...
# 50764              19     81641
# 51103              21     81966
# 51104              21     81966
# 51105              21     81966
# 51144              21     82043
#
#                                                UrlMandat  DateMandat  \
# 66     https://monespace.net-acheteur.com/Spa/app/#/m...  2012-09-11
# 189    https://monespace.net-acheteur.com/Spa/app/#/m...  2013-02-12
# 190    https://monespace.net-acheteur.com/Spa/app/#/m...  2013-02-12
# 191    https://monespace.net-acheteur.com/Spa/app/#/m...  2013-02-12
# 253    https://monespace.net-acheteur.com/Spa/app/#/m...  2013-03-17
# ...                                                  ...         ...
# 50764  https://monespace.net-acheteur.com/Spa/app/#/m...  2021-05-05
# 51103  https://monespace.net-acheteur.com/Spa/app/#/m...  2021-05-16
# 51104  https://monespace.net-acheteur.com/Spa/app/#/m...  2021-05-16
# 51105  https://monespace.net-acheteur.com/Spa/app/#/m...  2021-05-16
# 51144  https://monespace.net-acheteur.com/Spa/app/#/m...  2021-05-18
#
#        StatutMandat DateCompromis  BudgetMaxEuro  TypeBien  TypeProjet  \
# 66                0           NaN         300000         0           0
# 189               0           NaN         140000         0           1
# 190               0           NaN         140000         0           1
# 191               0           NaN         140000         0           1
# 253               0           NaN         500000         1           2
# ...             ...           ...            ...       ...         ...
# 50764             0           NaN         350000         0           0
# 51103             0           NaN         500000         0           0
# 51104             0           NaN         500000         0           0
# 51105             0           NaN         500000         0           0
# 51144             0           NaN         180000         0           0
#
#        SurfaceMin  NombrePieces  NombreChambres                     Ville  \
# 66             70             4               3               Montpellier
# 189            50             2               1   Lyon 1Er Arrondissement
# 190            50             2               1  Lyon 3Eme Arrondissement
# 191            50             2               1  Lyon 4Eme Arrondissement
# 253           120             4               3               Beaurecueil
# ...           ...           ...             ...                       ...
# 50764          40             2               1                   Puteaux
# 51103          70             3               2                    Frejus
# 51104          70             3               2                St Raphael
# 51105          70             3               2                    Fréjus
# 51144          40             3               2                  Toulouse
#
#        CodePostal       Departement                      Region  \
# 66          34000           Hérault        Languedoc-Roussillon
# 189         69001             Rhône                 Rhône-Alpes
# 190         69003             Rhône                 Rhône-Alpes
# 191         69004             Rhône                 Rhône-Alpes
# 253         13100  Bouches-du-Rhône  Provence-Alpes-Côte d'Azur
# ...           ...               ...                         ...
# 50764       92800    Hauts-de-Seine               Île-de-France
# 51103       83600               Var  Provence-Alpes-Côte d'Azur
# 51104       83700               Var  Provence-Alpes-Côte d'Azur
# 51105       83370               Var  Provence-Alpes-Côte d'Azur
# 51144       31000     Haute-Garonne               Midi-Pyrénées
#
#        NombreDeBiensTrouves  NombreDeBiensPublies  NombreDeBiensSelectionnes  \
# 66                      101                    46                          3
# 189                     112                    49                         14
# 190                     112                    49                         14
# 191                     112                    49                         14
# 253                     172                   102                         10
# ...                     ...                   ...                        ...
# 50764                   219                    15                          0
# 51103                   111                    49                          4
# 51104                   111                    49                          4
# 51105                   111                    49                          4
# 51144                   177                     9                          0
#
#        NombreDeBiensAVisiter  NombreDeBiensVisites  NombreDeBiensRejetes  \
# 66                         0                     2                    37
# 189                        0                    14                    19
# 190                        0                    14                    19
# 191                        0                    14                    19
# 253                        9                     1                    78
# ...                      ...                   ...                   ...
# 50764                      0                     0                    14
# 51103                      2                     0                    45
# 51104                      2                     0                    45
# 51105                      2                     0                    45
# 51144                      0                     0                     6
#
#        NombreDeBiensActesOuCompromis DatePremierePublicationDeBien  \
# 66                                 0                    2017-09-18
# 189                                0                    2013-03-02
# 190                                0                    2013-03-02
# 191                                0                    2013-03-02
# 253                                0                    2013-03-27
# ...                              ...                           ...
# 50764                              0                    2021-05-17
# 51103                              0                    2021-06-01
# 51104                              0                    2021-06-01
# 51105                              0                    2021-06-01
# 51144                              0                    2021-05-26
#
#       DateDernierePublicationDeBien  DelaiPremierePublicationDeBien  \
# 66                       2017-11-28                          1833.0
# 189                      2013-06-26                            18.0
# 190                      2013-06-26                            18.0
# 191                      2013-06-26                            18.0
# 253                      2013-08-29                            10.0
# ...                             ...                             ...
# 50764                    2021-06-09                            12.0
# 51103                    2021-06-20                            16.0
# 51104                    2021-06-20                            16.0
# 51105                    2021-06-20                            16.0
# 51144                    2021-06-23                             8.0
#
#       DatePremiereVisite  DelaiPremiereVisite
# 66            2017-10-06               1851.0
# 189                  NaN                  NaN
# 190                  NaN                  NaN
# 191                  NaN                  NaN
# 253                  NaN                  NaN
# ...                  ...                  ...
# 50764                NaN                  NaN
# 51103                NaN                  NaN
# 51104                NaN                  NaN
# 51105                NaN                  NaN
# 51144                NaN                  NaN
#
# [3877 rows x 32 columns]

# %%
df["UrlMandat"].

# %%
df_test = df.drop(["DateMandatInstant", "DateMandatYear", "MandatId", "UrlMandat","DateMandat", "DateCompromis", "Ville", "Departement", "Region", "DatePremierePublicationDeBien","NombreDeBiensTrouves","NombreDeBiensPublies", "NombreDeBiensSelectionnes", "NombreDeBiensAVisiter", "NombreDeBiensVisites", "NombreDeBiensRejetes", "DatePremierePublicationDeBien", "NombreDeBiensActesOuCompromis", "DateDernierePublicationDeBien","DelaiPremierePublicationDeBien", "DatePremiereVisite", "DelaiPremiereVisite"] , axis = 1)

# %%
plt.figure(figsize = (15,8))
corr = df_test.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True, 
    annot=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [raw]
# age du client
# code postal du client
#
# primo-accedants
# financement
#
# disponibilité

# %%
df.head()
# Out:
#    DateMandatInstant  DateMandatSeason  DateMandatYear  DateMandatMonth  \
# 0                  1                 2               0                4
# 1                  1                 2               0                4
# 3                  2                 2               0                4
# 7                 11                 2               0                5
# 9                 26                 2               0                5
#
#    DateMandatWeek  MandatId  \
# 0              17         2
# 1              17         2
# 3              17         5
# 7              19        17
# 9              21        79
#
#                                            UrlMandat  DateMandat  \
# 0  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-26
# 1  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-26
# 3  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-27
# 7  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-05-06
# 9  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-05-21
#
#    StatutMandat DateCompromis  BudgetMaxEuro  TypeBien  TypeProjet  \
# 0             0           NaN         280000         1           0
# 1             0           NaN         280000         1           0
# 3             0           NaN         250000         0           1
# 7             0           NaN         400000         1           0
# 9             0           NaN         240000         1           0
#
#    SurfaceMin NombrePieces NombreChambres        Ville  CodePostal  \
# 0           0            5              2        Nimes       30000
# 1           0            5              2  Montpellier       34000
# 3          60            3              2  Montpellier       34000
# 7         130            5              4       Lattes       34970
# 9          50            3              2       Poissy       78300
#
#   Departement                Region  NombreDeBiensTrouves  \
# 0        Gard  Languedoc-Roussillon                    39
# 1     Hérault  Languedoc-Roussillon                    39
# 3     Hérault  Languedoc-Roussillon                    18
# 7     Hérault  Languedoc-Roussillon                    11
# 9    Yvelines         Île-de-France                    14
#
#    NombreDeBiensPublies  NombreDeBiensSelectionnes  NombreDeBiensAVisiter  \
# 0                    32                          5                      4
# 1                    32                          5                      4
# 3                    17                          2                      0
# 7                    10                          3                      3
# 9                    14                          0                      0
#
#    NombreDeBiensVisites  NombreDeBiensRejetes  NombreDeBiensActesOuCompromis  \
# 0                     1                    18                              0
# 1                     1                    18                              0
# 3                     1                    11                              0
# 7                     0                     1                              0
# 9                     0                    12                              0
#
#   DatePremierePublicationDeBien DateDernierePublicationDeBien  \
# 0                    2012-05-21                    2015-10-09
# 1                    2012-05-21                    2015-10-09
# 3                    2012-05-03                    2014-11-18
# 7                    2012-06-07                    2012-07-06
# 9                    2012-05-31                    2012-08-17
#
#    DelaiPremierePublicationDeBien DatePremiereVisite  DelaiPremiereVisite
# 0                            25.0                NaN                  NaN
# 1                            25.0                NaN                  NaN
# 3                             6.0                NaN                  NaN
# 7                            32.0                NaN                  NaN
# 9                            10.0                NaN                  NaN

# %% [markdown]
# # Machine Learning

# %%
X = df.drop(["DateMandatInstant", "DateMandatYear", "MandatId", "UrlMandat","DateMandat","StatutMandat", "DateCompromis", "Ville", "Departement", "Region", "DatePremierePublicationDeBien","NombreDeBiensTrouves","NombreDeBiensPublies", "NombreDeBiensSelectionnes", "NombreDeBiensAVisiter", "NombreDeBiensVisites", "NombreDeBiensRejetes", "DatePremierePublicationDeBien", "NombreDeBiensActesOuCompromis", "DateDernierePublicationDeBien","DelaiPremierePublicationDeBien", "DatePremiereVisite", "DelaiPremiereVisite"],axis = 1)

# %%
y = df["StatutMandat"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2, random_state = 0, shuffle = True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

X_train, X_test, y_train, y_test= train_test_split(X,y, test_size= 0.2)
reg= linear_model.LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# Variance score
print('R²: %.2f' % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 0.23
# R²: 0.01

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='newton-cg')
from pprint import pprint
pprint("paramètre actuellement utiliés : \n")
pprint(lr.get_params())
lr.fit(X_train,y_train)
print(lr.score(X_train,y_train))
y_lr = lr.predict(X_test)
# On récupère la prédiction de la valeur positive
y_prob = lr.predict_proba(X_test)[:,1]
# Out:
# 'paramètre actuellement utiliés : \n'
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'newton-cg',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}
# 0.6540338321405335

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_lr,target_names = ['échec(Class 0)','succès (Class 1)']))
# Out:
#                   precision    recall  f1-score   support
#
#   échec(Class 0)       0.64      1.00      0.78      2965
# succès (Class 1)       0.46      0.00      0.01      1646
#
#         accuracy                           0.64      4611
#        macro avg       0.55      0.50      0.39      4611
#     weighted avg       0.58      0.64      0.51      4611

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

lr = LogisticRegression(solver = 'newton-cg')
params = {'C': np.logspace(-3, 3, 7) , 'penalty':['l1','l2'] }

lr_gs = GridSearchCV(lr, params, cv=10)
lr_gs.fit(X_train, y_train)

print(lr_gs.best_params_)
print("accuracy :",lr_gs.best_score_)

y_lr_gs = lr_gs.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_lr_gs, target_names = ['échec(Class 0)','succès (Class 1)']))
# Out:
# {'C': 0.001, 'penalty': 'l2'}
# accuracy : 0.6540338253707917
#                   precision    recall  f1-score   support
#
#   échec(Class 0)       0.64      1.00      0.78      2965
# succès (Class 1)       0.00      0.00      0.00      1646
#
#         accuracy                           0.64      4611
#        macro avg       0.32      0.50      0.39      4611
#     weighted avg       0.41      0.64      0.50      4611
