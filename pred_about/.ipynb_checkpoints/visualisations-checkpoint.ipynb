# %%
import pyodbc
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# %%
import statistics
import scipy.stats as stat
import scipy as sp

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

import warnings
warnings.filterwarnings('ignore')

# %%
df_BienMandat = pd.read_csv("BienMandat.csv")

# %%
df_BienMandat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426979 entries, 0 to 426978
# Data columns (total 65 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   BienMandatId                              426979 non-null  int64
#  1   Origine_UrlOrigineAnnonce                 413355 non-null  object
#  2   Origine_DateCollecte                      264234 non-null  object
#  3   Origine_OrigineCreationAnnonce            426979 non-null  int64
#  4   Origine_Commentaire                       239688 non-null  object
#  5   DescriptionBien_Titre                     424520 non-null  object
#  6   DescriptionBien_Description               420839 non-null  object
#  7   DescriptionBien_Adresse_Numero            39874 non-null   object
#  8   DescriptionBien_Adresse_Rue               67327 non-null   object
#  9   DescriptionBien_Adresse_BoitePostale      1617 non-null    object
# ...

# %%
df_BienMandat.head()
# Out:
#    BienMandatId Origine_UrlOrigineAnnonce     Origine_DateCollecte  \
# 0             1                       NaN  2013-10-01 20:33:47.970
# 1             2                       NaN  2013-10-01 20:33:48.237
# 2             3                       NaN  2013-10-01 20:33:48.407
# 3             4                       NaN  2013-10-01 20:33:48.487
# 4             5                       NaN  2013-10-01 20:33:48.687
#
#    Origine_OrigineCreationAnnonce Origine_Commentaire DescriptionBien_Titre  \
# 0                               3                 NaN             Annonce 1
# 1                               3                 NaN            Annonce 2
# 2                               3                 NaN            Annonce 3
# 3                               3                 NaN            Annonce 4
# 4                               3                 NaN             Annonce 5
#
#                          DescriptionBien_Description  \
# ...

# %%
import plotly.graph_objects as go
df_test = df_25["Origine_DateCollecte"]
line(df_test, x = 'date', y = 'GOOG')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# C:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Origine_DateCollecte'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_BienMandat.isnull().sum()
# Out:
# BienMandatId                           0
# Origine_UrlOrigineAnnonce          13624
# Origine_DateCollecte              162745
# Origine_OrigineCreationAnnonce         0
# Origine_Commentaire               187291
#                                    ...
# ContactBien_Nom                   419522
# ContactBien_Email                 423242
# ContactBien_Telephone             421664
# Origine_ExternalId                414904
# BienPreStockMandatId              421565
# Length: 65, dtype: int64

# %%
df_10 = df_BienMandat['Origine_UrlOrigineAnnonce']

# %%
value_count = df_BienMandat["Origine_UrlOrigineAnnonce"].value_counts()
to_keep_25 = value_count[value_count >=100].index
liste_25 = to_keep_25.to_list()
liste_25
# Out:
# ['https://www.orpi.com',
#  'https://www.safti.fr',
#  'https://www.iadfrance.fr',
#  'https://www.leboncoin.fr',
#  'http://www.agencyimmo03.fr',
#  'https://www.credotimmobilier.com',
#  'https://www.leboncoin.fr/',
#  'https://www.bourse-immobilier.fr',
#  'https://www.agencyimmo03.fr',
#  'https://www.cpcinvest.fr',
#  'https://www.immo64.fr',
#  'https://www.arthurimmo.com']

# %%
df_25 = df_BienMandat.loc[df_BienMandat['Origine_UrlOrigineAnnonce'].isin(liste_25)]

# %%
df_25['Origine_UrlOrigineAnnonce'].value_counts()
# Out:
# https://www.orpi.com                556
# https://www.safti.fr                469
# https://www.iadfrance.fr            409
# https://www.leboncoin.fr            404
# http://www.agencyimmo03.fr          352
# https://www.credotimmobilier.com    332
# https://www.leboncoin.fr/           209
# https://www.bourse-immobilier.fr    156
# https://www.agencyimmo03.fr         131
# https://www.cpcinvest.fr            117
# https://www.immo64.fr               112
# https://www.arthurimmo.com          100
# Name: Origine_UrlOrigineAnnonce, dtype: int64

# %%
plt.figure(figsize = (12,6))
plt.plot(df_25['Origine_UrlOrigineAnnonce'])

# %%
df_25.head()
# Out:
#         BienMandatId         Origine_UrlOrigineAnnonce Origine_DateCollecte  \
# 105156        108222        https://www.arthurimmo.com                  NaN
# 106110        109176  https://www.credotimmobilier.com                  NaN
# 106127        109193          https://www.leboncoin.fr                  NaN
# 106262        109328          https://www.leboncoin.fr                  NaN
# 106846        109912          https://www.leboncoin.fr                  NaN
#
#         Origine_OrigineCreationAnnonce Origine_Commentaire  \
# 105156                               0                 NaN
# 106110                               0                 NaN
# 106127                               0                 NaN
# 106262                               0                 NaN
# 106846                               0                 NaN
#
#          DescriptionBien_Titre  \
# 105156  Maison 4 pièces 100 m²
# 106110               Immeuble
# 106127               Immeuble
# ...

# %%
import plotly.express as px
# This dataframe has 244 lines, but 4 distinct values for `day`
df_25 = px.data.tips()
fig = px.pie(df_25, values='tip', names='time')
fig.show()
# Out:
# <div>                            <div id="b7142494-9d2d-4a31-828b-6847ad882373" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7142494-9d2d-4a31-828b-6847ad882373")) {                    Plotly.newPlot(                        "b7142494-9d2d-4a31-828b-6847ad882373",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"time=%{label}<br>tip=%{value}<extra></extra>","labels":["Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Di
# ...

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=df_25,y=df_25['Origine_UrlOrigineAnnonce'])
plt.title("CustumerType frenquency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# C:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Origine_UrlOrigineAnnonce'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_25.value_counts().hvplot.help('line')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\LOUDOU~1\AppData\Local\Temp/ipykernel_29184/2810695955.py in <module>
# ----> 1 df_25.value_counts().hvplot.help('line')
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
hvplot.help('barh')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\LOUDOU~1\AppData\Local\Temp/ipykernel_29184/1814073879.py in <module>
# ----> 1 hvplot.help('barh')
#
# NameError: name 'hvplot' is not defined

# %%
import hvplot
import hvplot.pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\LOUDOU~1\AppData\Local\Temp/ipykernel_29184/2771015700.py in <module>
# ----> 1 import hvplot
#       2 import hvplot.pandas
#
# C:\anaconda3\lib\site-packages\hvplot\__init__.py in <module>
#       6
#       7 import param
# ----> 8 import holoviews as _hv
#       9
#      10 from holoviews import Store
#
# C:\anaconda3\lib\site-packages\holoviews\__init__.py in <module>
#      10
#      11 from . import util                                       # noqa (API import)
# ---> 12 from .annotators import annotate                         # noqa (API import)
#      13 from .core import archive, config                        # noqa (API import)
#      14 from .core.boundingregion import BoundingBox             # noqa (API import)
#
# C:\anaconda3\lib\site-packages\holoviews\annotators.py in <module>
#       8 import param
# ...

# %%
from hvplot import hvPlot
import holoviews as hv
hv.extension('bokeh')

plot = hvPlot(df_BienMandat)
plot(y=['DescriptionBien_Prix'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\LOUDOU~1\AppData\Local\Temp/ipykernel_29184/4071442822.py in <module>
# ----> 1 from hvplot import hvPlot
#       2 import holoviews as hv
#       3 hv.extension('bokeh')
#       4
#       5 plot = hvPlot(df_BienMandat)
#
# C:\anaconda3\lib\site-packages\hvplot\__init__.py in <module>
#       6
#       7 import param
# ----> 8 import holoviews as _hv
#       9
#      10 from holoviews import Store
#
# C:\anaconda3\lib\site-packages\holoviews\__init__.py in <module>
#      10
#      11 from . import util                                       # noqa (API import)
# ---> 12 from .annotators import annotate                         # noqa (API import)
#      13 from .core import archive, config                        # noqa (API import)
#      14 from .core.boundingregion import BoundingBox             # noqa (API import)
#
# ...

# %%
df_BienMandat['Origine_UrlOrigineAnnonce'].value_counts().hvplot.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\LOUDOU~1\AppData\Local\Temp/ipykernel_29184/3974452384.py in <module>
# ----> 1 df_BienMandat['Origine_UrlOrigineAnnonce'].value_counts().hvplot.bar()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'hvplot'

# %%
sort = df_25['Origine_UrlOrigineAnnonce'].argsort()

# %%
plt.figure(figsize=(30,30))
sorted_idx = df_25['Origine_UrlOrigineAnnonce'].argsort()
plt.barh(df_25['Origine_UrlOrigineAnnonce'][sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# C:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Origine_UrlOrigineAnnonce'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_BienMandat['Origine_UrlOrigineAnnonce'].value_counts()
# Out:
# https://www.orpi.com                                                                  556
# https://www.safti.fr                                                                  469
# https://www.iadfrance.fr                                                              409
# https://www.leboncoin.fr                                                              404
# http://www.agencyimmo03.fr                                                            352
#                                                                                      ...
# http://www.seloger.com/annonces/achat/appartement/nimes-30/esplanade/120509511.htm      1
# https://www.leboncoin.fr/ventes_immobilieres/1989504476.htm                             1
# https://www.leboncoin.fr/ventes_immobilieres/1639288105.htm                             1
# http://www.leboncoin.fr/ventes_immobilieres/617234988.htm?ca=13_s                       1
# ...

# %%
# 25 valeurs les plus grandes et faire un plot avec avec

# %%
df_BienMandat_url = df_BienMandat.groupby('Origine_UrlOrigineAnnonce')
df_BienMandat_url.head()
# Out:
#         BienMandatId                          Origine_UrlOrigineAnnonce  \
# 0                  1                                                NaN
# 1                  2                                                NaN
# 2                  3                                                NaN
# 3                  4                                                NaN
# 4                  5                                                NaN
# ...              ...                                                ...
# 426969        432025  https://www.leboncoin.fr/bureaux_commerces/200...
# 426970        432026  https://www.logic-immo.com/detail-vente-6A8FD2...
# 426971        432027  https://www.logic-immo.com/detail-vente-170AEC...
# 426977        432033  https://www.seloger.com/annonces/achat/apparte...
# 426978        432034  https://www.leboncoin.fr/bureaux_commerces/206...
#
#            Origine_DateCollecte  Origine_OrigineCreationAnnonce  \
# ...

# %%
df_BienMandat['Origine_DateCollecte'].value_counts()
# Out:
# 2021-04-28 11:14:11.100    72
# 2021-06-22 17:11:58.377    63
# 2021-06-18 16:25:21.283    59
# 2021-05-22 15:54:56.237    59
# 2021-05-03 08:43:56.227    58
#                            ..
# 2019-10-01 18:00:36.227     1
# 2020-12-08 10:36:57.070     1
# 2014-02-06 14:40:51.457     1
# 2017-02-20 13:34:01.163     1
# 2020-06-02 08:01:51.230     1
# Name: Origine_DateCollecte, Length: 176150, dtype: int64

# %%
server = 'sql-mcibusxrm-dev.database.windows.net'
database = 'sqldb-mcibusxrm-dev'
username = 'sql-mcibusxrm-dev'
password = '{pzR28UcutX26GdAJLWm9SXw}'
driver= '{ODBC Driver 17 for SQL Server}'

conn = pyodbc.connect('DRIVER='+driver+';SERVER=tcp:'+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = conn.cursor()
#cursor.execute("SELECT TOP 100000 Lieu FROM dbo.Criteres")

# %%
def HandleHierarchyId(v):
    return str(v)
conn = pyodbc.connect('DRIVER='+driver+';SERVER=tcp:'+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password)
conn.add_output_converter(-151, HandleHierarchyId)

# %%
df0 = pd.read_sql("SELECT * FROM dbo.BienMandat ", conn)
df0.head()

# %%
df0 = pd.read_sql("SELECT * FROM dbo.Criteres ", conn)
df0.head()

# %%
df = pd.read_csv("test.csv", sep = ",")
df.head()

# %%
df.drop(["Unnamed: 0"], axis=1, inplace = True)

# %%
df.head()

# %%
succes_par_annee = df[["DateMandatYear","StatutMandat"]].groupby("DateMandatYear").aggregate(np.sum)
succes_par_annee.plot();
