# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import scipy.stats as stat
import scipy as sp
import statistics

# %%
df = pd.read_csv("test.csv", sep = ",")
df.head(2)
# Out:
# C:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0  DateMandatInstant  DateMandatSeason  DateMandatYear  \
# 0           0                  1                 2               0
# 1           1                  1                 2               0
#
#    DateMandatMonth  DateMandatWeek  MandatId  \
# 0                4              17         2
# 1                4              17         2
#
#                                            UrlMandat  DateMandat  \
# 0  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-26
# 1  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-26
#
#    StatutMandat DateCompromis  BudgetMaxEuro  TypeBien  TypeProjet  \
# 0             0           NaN         280000         1           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51817 entries, 0 to 51816
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      51817 non-null  int64
#  1   DateMandatInstant               51817 non-null  int64
#  2   DateMandatSeason                51817 non-null  int64
#  3   DateMandatYear                  51817 non-null  int64
#  4   DateMandatMonth                 51817 non-null  int64
#  5   DateMandatWeek                  51817 non-null  int64
#  6   MandatId                        51817 non-null  int64
#  7   UrlMandat                       51817 non-null  object
#  8   DateMandat                      51817 non-null  object
#  9   StatutMandat                    51817 non-null  int64
#  10  DateCompromis                   6645 non-null   object
#  11  BudgetMaxEuro                   51817 non-null  int64
# ...

# %%
df.shape
# Out:
# (51817, 33)

# %%
# obtenir 25% des données

25*51817/100
# Out:
# 12954.25

# %%
df_test = df.iloc[:12954,:]

# %%
df_test.shape
# Out:
# (12954, 33)

# %%
df_test.tail()
# Out:
#        Unnamed: 0  DateMandatInstant  DateMandatSeason  DateMandatYear  \
# 12949       12949               2084                 1               6
# 12950       12950               2084                 1               6
# 12951       12951               2085                 1               6
# 12952       12952               2085                 1               6
# 12953       12953               2085                 1               6
#
#        DateMandatMonth  DateMandatWeek  MandatId  \
# 12949                1               2     40219
# 12950                1               2     40230
# 12951                1               2     40249
# 12952                1               2     40249
# 12953                1               2     40249
#
#                                                UrlMandat  DateMandat  \
# 12949  https://monespace.net-acheteur.com/Spa/app/#/m...  2018-01-08
# 12950  https://monespace.net-acheteur.com/Spa/app/#/m...  2018-01-08
# ...

# %%
df_test["StatutMandat"].value_counts()
# Out:
# 0    11407
# 1     1547
# Name: StatutMandat, dtype: int64

# %%
11407-1547
# Out:
# 9860

# %%
df_drop = df_test[df_test["StatutMandat"] == 0]

# %%
df_drop2 = df_drop.iloc[:1547,:]

# %%
df_drop2.shape
# Out:
# (1547, 33)

# %%
# transformer en csv  les deux
# je veux entrainer modele big dataset
# tester le modèle avec les données équilibrées

# %%
#dump
#load()


X = df.drop["statutmandat"]
y =

# %%
df_drop.head()
# Out:
#    Unnamed: 0  DateMandatInstant  DateMandatSeason  DateMandatYear  \
# 0           0                  1                 2               0
# 1           1                  1                 2               0
# 2           2                  1                 2               0
# 3           3                  2                 2               0
# 4           4                  7                 2               0
#
#    DateMandatMonth  DateMandatWeek  MandatId  \
# 0                4              17         2
# 1                4              17         2
# 2                4              17         3
# 3                4              17         5
# 4                5              18        12
#
#                                            UrlMandat  DateMandat  \
# 0  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-26
# 1  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-26
# 2  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-04-26
# ...

# %%
df_test2 = df.iloc[12954:,:]

# %%
df_test2.shape
# Out:
# (38863, 33)

# %%
df_test2.head()
# Out:
#        Unnamed: 0  DateMandatInstant  DateMandatSeason  DateMandatYear  \
# 12954       12954               2085                 1               6
# 12955       12955               2085                 1               6
# 12956       12956               2085                 1               6
# 12957       12957               2085                 1               6
# 12958       12958               2085                 1               6
#
#        DateMandatMonth  DateMandatWeek  MandatId  \
# 12954                1               2     40249
# 12955                1               2     40249
# 12956                1               2     40249
# 12957                1               2     40249
# 12958                1               2     40284
#
#                                                UrlMandat  DateMandat  \
# 12954  https://monespace.net-acheteur.com/Spa/app/#/m...  2018-01-09
# 12955  https://monespace.net-acheteur.com/Spa/app/#/m...  2018-01-09
# ...
