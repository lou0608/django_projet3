# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import scipy.stats as stat
import scipy as sp
import statistics

# %%
df = pd.read_csv("rhone-alpes.csv", sep = ',')
df.head()
# Out:
#    DateMandatInstant  DateMandatSeason  DateMandatYear  DateMandatMonth  \
# 0                 33                 2               0                5
# 1                 48                 2               0                6
# 2                 57                 3               0                6
# 3                139                 3               0                9
# 4                154                 4               0                9
#
#    DateMandatWeek  MandatId  \
# 0              22       122
# 1              24       220
# 2              25       247
# 3              37       686
# 4              39       867
#
#                                            UrlMandat  DateMandat  \
# 0  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-05-28
# 1  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-06-12
# 2  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-06-21
# 3  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-09-11
# ...

# %%
plot = df['StatutMandat'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='StatutMandat')

# %%
df2 = pd.read_csv('Île-de-France.csv', sep=',')

# %%
df2.head()
# Out:
#    DateMandatInstant  DateMandatSeason  DateMandatYear  DateMandatMonth  \
# 0                  9                 2               0                5
# 1                 22                 2               0                5
# 2                 26                 2               0                5
# 3                 31                 2               0                5
# 4                 59                 3               0                6
#
#    DateMandatWeek  MandatId  \
# 0              18        14
# 1              20        54
# 2              21        79
# 3              21       132
# 4              25       255
#
#                                            UrlMandat  DateMandat  \
# 0  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-05-04
# 1  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-05-17
# 2  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-05-21
# 3  https://monespace.net-acheteur.com/Spa/app/#/m...  2012-05-26
# ...

# %%
plot = df2['StatutMandat'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='StatutMandat')

# %%
df3 = pd.read_csv('Midi-Pyrénées.csv', sep=',')

# %%
plot = df3['StatutMandat'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='StatutMandat')

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Modèle de ML
from sklearn import linear_model

# data pre-processing
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# Outils score et evaluation de modèle
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import r2_score

# Outils optmisation de modèle
from sklearn.model_selection import GridSearchCV
