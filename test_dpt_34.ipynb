# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("test.csv")
df = df.drop(["Unnamed: 0"], axis = 1)

# %%
df.head(50)
# Out:
#     MandatId  Statut  SurfaceMin  NombrePiecesEnum  NombreChambresEnum  \
# 0          2       7           0                 5                   2
# 1          5       7          60                 3                   2
# 2         78       7          90                 4                   3
# 3         81       7          90                 3                   2
# 4       1374       7          70                 3                   2
# 5       1917       7          50                 3                   2
# 6       2039       7           0                 0                   0
# 7       2041       7          30                 2                   1
# 8       2088       7          25                 1                   1
# 9       2625       7           0                 2                   1
# 10      3134       7           0                 2                   1
# 11      3201       7          80                 3                   2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   MandatId               363 non-null    int64
#  1   Statut                 363 non-null    int64
#  2   SurfaceMin             363 non-null    int64
#  3   NombrePiecesEnum       363 non-null    int64
#  4   NombreChambresEnum     363 non-null    int64
#  5   TypeProjet             363 non-null    int64
#  6   TypeBien               363 non-null    int64
#  7   Region_LocalisationId  363 non-null    int64
#  8   BudgetMaxEuro          363 non-null    int64
#  9   CodePostal             363 non-null    int64
#  10  Departement            363 non-null    object
#  11  dpt                    363 non-null    int64
# dtypes: int64(11), object(1)
# memory usage: 34.2+ KB
